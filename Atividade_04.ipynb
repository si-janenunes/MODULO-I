# %% [markdown]
# <a href="https://colab.research.google.com/github/si-janenunes/MODULO-I/blob/main/Atividade_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CENTRO DE EDUCAÇÃO DE TECNOLOGIA DO AMAZONAS - IBC
#
# **MANAUS 24 DE MARÇO DE 2026**
#
# **AlunA**: *Rojane Nunes *

# %%
nu1 = 10 # Atribuindo um valor inteiro a nu1
nu2 = 10 # Atribuindo um valor inteiro a nu2
print (' Olá mundo!')

print (5+5-2)
print (nu1) # Usando nu1 em vez de n1
print (5**2)
print (nu2) # Usando nu2 em vez de n2
# Out:
#  Olá mundo!
# 8
# 10
# 25
# 10

# %%
# script 1
# Função criada pelo usuário
def dobro (x):
  print (x * 2)

dobro (125)
# Out:
# 250
